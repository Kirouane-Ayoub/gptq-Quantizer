# %%
# !pip install gptq-Quantizer==1.0

# %%
from gptq_Quantizer import gptq_Quantizer

# %%
llm_quantizer = gptq_Quantizer.Quantizer("facebook/opt-125m" )
llm_quantizer.run(bits =4 ,
                  block_name_to_quantize="model.decoder.layers",
                  model_seqlen = 2048 ,
                  save_folder = "new_model/")
# Out:
# ...
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# ...
# Quantizing layers inside the block:   0%|          | 0/6 [00:00<?, ?it/s]
# WARNING:optimum.gptq.quantizer:Found modules on cpu/disk. Using Exllama backend requires all the modules to be on GPU. Setting `disable_exllama=True`
# opt-125m has been quantized successfully and saved here new_model/

# %%
from gptq_Quantizer.utils import Load

# %%
quantized_model = Load(model_name="facebook/opt-125m" , save_folder="/content/new_model")
